# %%
import os
from datetime import datetime
import time
import random
import cv2
import pandas as pd
import numpy as np
from glob import glob
import re

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
marking = pd.read_csv('I:\\My Drive\\UAS_Beans\\Beans_StandCount\\2022\\SVREC\\ByStep\\k._TestingModel\\6_13_22_SVREC_RGB_6m\\Annotatios\\6_13_22_SVREC_RGB_6m_csv.csv',index_col = False)
ROOT_IMG = 'I:\\My Drive\\UAS_Beans\\Beans_StandCount\\2022\\SVREC\\ByStep\\k._TestingModel\\6_13_22_SVREC_RGB_6m\\Plots_Clip'
#%cd /content/drive/MyDrive/MSU_beans/2022/Drone_pheno/SVREC/22_SVREC_RGB_7m_img/
marking
# Out:
#               filename  file_size file_attributes  region_count  region_id  \
# 0     2201_1007_6m.png    5265135              {}           134          0
# 1     2201_1007_6m.png    5265135              {}           134          1
# 2     2201_1007_6m.png    5265135              {}           134          2
# 3     2201_1007_6m.png    5265135              {}           134          3
# 4     2201_1007_6m.png    5265135              {}           134          4
# ...                ...        ...             ...           ...        ...
# 2586  2201_3011_6m.png    5591433              {}           147        142
# 2587  2201_3011_6m.png    5591433              {}           147        143
# 2588  2201_3011_6m.png    5591433              {}           147        144
# 2589  2201_3011_6m.png    5591433              {}           147        145
# 2590  2201_3011_6m.png    5591433              {}           147        146
#
#                                 region_shape_attributes  \
# 0     {"name":"rect","x":713,"y":127,"width":45,"hei...
# 1     {"name":"rect","x":765,"y":134,"width":28,"hei...
# 2     {"name":"rect","x":799,"y":146,"width":33,"hei...
# 3     {"name":"rect","x":831,"y":129,"width":36,"hei...
# 4     {"name":"rect","x":874,"y":146,"width":48,"hei...
# ...                                                 ...
# 2586  {"name":"rect","x":3841,"y":173,"width":19,"he...
# 2587  {"name":"rect","x":3669,"y":498,"width":56,"he...
# 2588  {"name":"rect","x":3721,"y":505,"width":27,"he...
# 2589  {"name":"rect","x":3793,"y":512,"width":24,"he...
# 2590  {"name":"rect","x":3806,"y":495,"width":47,"he...
#
#                 region_attributes
# 0     {"bean_1":{"1_plant":true}}
# 1     {"bean_1":{"1_plant":true}}
# 2     {"bean_1":{"1_plant":true}}
# 3     {"bean_1":{"1_plant":true}}
# 4     {"bean_1":{"1_plant":true}}
# ...                           ...
# 2586  {"bean_1":{"1_plant":true}}
# 2587  {"bean_1":{"1_plant":true}}
# 2588  {"bean_1":{"1_plant":true}}
# 2589  {"bean_1":{"1_plant":true}}
# 2590  {"bean_1":{"1_plant":true}}
#
# [2591 rows x 7 columns]

# %%
## Showing images from directory and image format
img_list = os.listdir(ROOT_IMG)
img_list = [v for v in img_list if v.endswith('.png')]
print(img_list)
len(img_list)
# Out:
# ['2201_3035_6m.png', '2201_3034_6m.png', '2201_3033_6m.png', '2201_3032_6m.png', '2201_3031_6m.png', '2202_4021_6m.png', '2202_4022_6m.png', '2202_4023_6m.png', '2202_4024_6m.png', '2202_4025_6m.png', '2201_3023_6m.png', '2201_3022_6m.png', '2201_3021_6m.png', '2201_3020_6m.png', '2201_3019_6m.png', '2202_4011_6m.png', '2202_4012_6m.png', '2202_4013_6m.png', '2202_4014_6m.png', '2202_4015_6m.png', '2201_3011_6m.png', '2201_3010_6m.png', '2201_3009_6m.png', '2201_3008_6m.png', '2201_3007_6m.png', '2202_4001_6m.png', '2202_4002_6m.png', '2202_4003_6m.png', '2202_4004_6m.png', '2202_4005_6m.png', '2201_1035_6m.png', '2201_1034_6m.png', '2201_1033_6m.png', '2201_1032_6m.png', '2201_1031_6m.png', '2202_2021_6m.png', '2202_2022_6m.png', '2202_2023_6m.png', '2202_2024_6m.png', '2202_2025_6m.png', '2201_1023_6m.png', '2201_1022_6m.png', '2201_1021_6m.png', '2201_1020_6m.png', '2201_1019_6m.png', '2202_2011_6m.png', '2202_2012_6m.png', '2202_2013_6m.png', '2202_2014_6m.png', '2202_2015_6m.png', '2201_1011_6m.png', '2201_1010_6m.png', '2201_1009_6m.png', '2201_1008_6m.png', '2201_1007_6m.png', '2202_2001_6m.png', '2202_2002_6m.png', '2202_2003_6m.png', '2202_2004_6m.png', '2202_2005_6m.png']
# 60

# %%
coord_list = []
for img in img_list:
    lista = marking[marking.filename == img] 
    tamanho = lista.shape

    if tamanho[0] != 0:
        imagem = cv2.imread(os.path.join(ROOT_IMG, img)) 
        img_size = imagem.shape

        for i in range(tamanho[0]):
            line = lista.iloc[i,:] 
            region_shape = line.region_shape_attributes 
            region_attributes = (line.region_attributes)
            region_attributes = re.findall('"([^"]*)"', region_attributes) 
            coords = [float(s) for s in re.findall(r'-?\d+\.?\d*', region_shape)]
            x = int(coords[0]) 
            y = int(coords[1]) 
            w = int(coords[2]) 
            h = int(coords[3]) 
            
            coord_list.append([img.split('.')[0],img_size[1], img_size[0], x,y,w,h, "bean"]) ## saving coord

coord_list2 = np.array(coord_list)

print(coord_list2)
# Out:
# [['2201_3011_6m' '3872' '640' ... '25' '34' 'bean']
#  ['2201_3011_6m' '3872' '640' ... '20' '22' 'bean']
#  ['2201_3011_6m' '3872' '640' ... '34' '20' 'bean']
#  ...
#  ['2201_1007_6m' '3872' '640' ... '28' '61' 'bean']
#  ['2201_1007_6m' '3872' '640' ... '23' '28' 'bean']
#  ['2201_1007_6m' '3872' '640' ... '45' '23' 'bean']]

# %%
# generating the Pandas dataframe
# from the Numpy array and specifying
# name of index and columns
panda_df = pd.DataFrame(data = coord_list2[0:, 0:],
                        index = [str(i + 1) 
                        for i in range(coord_list2.shape[0])],
                        columns = ['image_id', 'width', 'height', 'x','y','w','h','source'])
  
# printing the dataframe

panda_df
# Out:
#           image_id width height    x    y   w   h source
# 1     2201_3011_6m  3872    640   33  139  25  34   bean
# 2     2201_3011_6m  3872    640  135  151  20  22   bean
# 3     2201_3011_6m  3872    640  191  140  34  20   bean
# 4     2201_3011_6m  3872    640  253  134  33  25   bean
# 5     2201_3011_6m  3872    640  293  145  23  31   bean
# ...            ...   ...    ...  ...  ...  ..  ..    ...
# 2587  2201_1007_6m  3872    640  174  435  23  36   bean
# 2588  2201_1007_6m  3872    640  119  430  26  37   bean
# 2589  2201_1007_6m  3872    640   83  416  28  61   bean
# 2590  2201_1007_6m  3872    640   62  424  23  28   bean
# 2591  2201_1007_6m  3872    640    5  432  45  23   bean
#
# [2591 rows x 8 columns]

# %%
## Saving in COCO annotations format
panda_df['bbox'] = panda_df[panda_df.columns[3:7]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)

panda_df = panda_df.drop(panda_df.columns[3:7], axis=1)
panda_df['bbox'] = '[' + panda_df['bbox'].astype(str) + ']'

panda_df
# Out:
#           image_id width height source             bbox
# 1     2201_3011_6m  3872    640   bean   [33,139,25,34]
# 2     2201_3011_6m  3872    640   bean  [135,151,20,22]
# 3     2201_3011_6m  3872    640   bean  [191,140,34,20]
# 4     2201_3011_6m  3872    640   bean  [253,134,33,25]
# 5     2201_3011_6m  3872    640   bean  [293,145,23,31]
# ...            ...   ...    ...    ...              ...
# 2587  2201_1007_6m  3872    640   bean  [174,435,23,36]
# 2588  2201_1007_6m  3872    640   bean  [119,430,26,37]
# 2589  2201_1007_6m  3872    640   bean   [83,416,28,61]
# 2590  2201_1007_6m  3872    640   bean   [62,424,23,28]
# 2591  2201_1007_6m  3872    640   bean    [5,432,45,23]
#
# [2591 rows x 5 columns]

# %%
panda_df.to_csv('I:\\My Drive\\UAS_Beans\\Beans_StandCount\\2022\\SVREC\\ByStep\\k._TestingModel\\6_13_22_SVREC_RGB_6m\\Annotatios\\6_13_22_SVREC_RGB_6m_csv__2.csv', index=False)
